# %% [markdown]
# # Homework 4-1

# %%
from datlib.plots import * 
from datlib.FRED import *
data_codes  = {"Unemployment Rate": "UNRATENSA",
               "Seasonally Adjusted Unemployment Rate": "UNRATE",
              "Nominal Potential Gross Domestic Product" : "NGDPPOT",
              "Nominal GDP" : "GDP",
              "CPI" : "CPIAUCSL",
              "Case-Shiller Housing Price Index" : "CSUSHPINSA"}
start = datetime.datetime(2000, 10, 1)
end = datetime.datetime.today()
data = gather_data(data_codes = data_codes, start = start, end = end, freq = "Q")
data
# Out:
#             Unemployment Rate  Seasonally Adjusted Unemployment Rate  \
# DATE
# 2000-12-31           3.666667                               3.900000
# 2001-03-31           4.600000                               4.233333
# 2001-06-30           4.333333                               4.400000
# 2001-09-30           4.766667                               4.833333
# 2001-12-31           5.233333                               5.500000
# ...                       ...                                    ...
# 2019-09-30           3.700000                               3.633333
# 2019-12-31           3.333333                               3.533333
# 2020-03-31           4.100000                               3.833333
# 2020-06-30          12.866667                              13.033333
# 2020-09-30           8.900000                               8.833333
#
#             Nominal Potential Gross Domestic Product  Nominal GDP         CPI  \
# DATE
# ...

# %%
def plot_lines(df, linewidth = 20, figsize = (40,20), legend = True, pp = None):
    fig, ax = plt.subplots(figsize = figsize)
    df.plot.line(linewidth = linewidth, ax = ax, legend = legend)
    #Rotate the  the text at x axis 
    ax.tick_params(axis = "x", rotation=90)
    #no tick lines
    ax.tick_params("both", length =0, which = "both")
    
    vals = ax.get_yticks()
    vals = [int(x) for x in vals]
    ax.set_yticklabels(vals)
    
    remove_chars = "[]:$'\\"
    filename = str(list(df.keys()))
    for char in remove_chars:
        filename = filename.replace(char, "")
    plt.savefig(filename[:50] + "line.png",
               bbox_inches = "tight")
    if pp != None: pp.savefig(fig, box_inches = "tight")

# %%
plt.rcParams.update({"font.size":24})
UNEMRATES = ["Unemployment Rate",
              "Seasonally Adjusted Unemployment Rate"]
plot_lines(df = data[UNEMRATES], linewidth = 5, figsize = (20, 10), pp = None)

plot_ts_scatter(data[UNEMRATES])
# Out:
# C:\Users\james\James-Clark-s-Python-Portfolio\Homework\datlib\plots.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] =[int(str(ind)[:4]) for ind in df.index]

# %%
plt.rcParams.update({"font.size":24})
GDP = ["Nominal GDP",
              "Nominal Potential Gross Domestic Product"]
plot_lines(df = data[GDP], linewidth = 5, figsize = (20, 10), pp = None)
plot_ts_scatter(data[GDP])
# Out:
# C:\Users\james\James-Clark-s-Python-Portfolio\Homework\datlib\plots.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] =[int(str(ind)[:4]) for ind in df.index]

# %%
plt.rcParams.update({"font.size":24})
HOUSINGCPI = ["CPI",
              "Case-Shiller Housing Price Index"]
plot_lines(df = data[HOUSINGCPI], linewidth = 5, figsize = (20, 10), pp = None)
plot_ts_scatter(data[HOUSINGCPI])
# Out:
# C:\Users\james\James-Clark-s-Python-Portfolio\Homework\datlib\plots.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] =[int(str(ind)[:4]) for ind in df.index]
